# %% [markdown]
# <a href="https://colab.research.google.com/github/SShalini24/Insurance-Cost-Prediction-using-PyCaret/blob/main/PyCaret_for_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PyCaret For Regression (Health Insurance Cost Prediction)

# %% [markdown]
# PyCaret is an open-source, low code machine learning library in Python that automates machine learning workflows.
#
# It is an end-to-end machine learning and model management tool that speeds up the experiment cycle exponentially and makes you more productive.
#
# It is a bundle of many machine learning algorithms.
#
# Only three lines of codes is required to compare 20 ML Models.
#
#   Classification
#   Regression
#   Clustering

# %% [markdown]
# # Install PyCaret

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.4/484.4 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 5.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 76.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Get the Version of the PyCaret

# %%
from pycaret.utils import version
version()
# Out:
# '3.0.4'

# %% [markdown]
# # Get the list of Datasets available in the PyCaret

# %%
from pycaret.datasets import get_data
dataset = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# # Get the Insurance Dataset

# %%
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Parameter Setting for all "Regression Models"

# %%
from pycaret.regression import *
s = setup(data = data , target='charges',train_size=0.70)
# Out:
# <style type="text/css">
# #T_b926f_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b926f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b926f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b926f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b926f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b926f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b926f_row0_col1" class="data row0 col1" >3738</td>
#     </tr>
#     <tr>
#       <th id="T_b926f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b926f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b926f_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_b926f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # "Run and Compare" Model Performance

# %%
cm = compare_models()
# Out:
# <style type="text/css">
# #T_db32e th {
#   text-align: left;
# }
# ...

# %% [markdown]
# # Three Lines of Code For Model Comparision for "Insurance" dataset.

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

dataset = get_data('insurance')
s = setup(data=dataset,target = 'charges')
cm = compare_models()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_b3dc7_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b3dc7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3dc7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b3dc7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3dc7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3dc7_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %% [markdown]
# # Build Single Model "Gradient Boosting Regressor"

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

data = get_data('insurance')
s = setup(data = data, target='charges')
model = create_model('gbr')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_7bc1a_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7bc1a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bc1a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7bc1a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bc1a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7bc1a_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %% [markdown]
# # "Save" The Trained Model

# %%
sm = save_model(model,' model_save_grb')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# # Load The Model "Make Predictions on Unseen Data"

# %% [markdown]
# # Load The Model

# %%
model = load_model('/content/ model_save_grb')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# # Make The Predictions on "New Unseen Data".

# %%
import pandas as pd

# %%
data = {'age':40,
        'sex':1,
        'bmi':40.30,
        'children':4,
        'smoker':1,
        'region':2}

df = pd.DataFrame(data,index=[0])
df
# Out:
#    age  sex   bmi  children  smoker  region
# 0   40    1  40.3         4       1       2

# %%
predict = predict_model(model,df)

# %%
predict
# Out:
#    age  sex        bmi  children  smoker  region  prediction_label
# 0   40    1  40.299999         4       1       2       9791.269026

# %% [markdown]
# # Thank You
